# %%
import pandas as pd

# %%
ls
# Out:
# consulta-base-datos.ipynb*  Ejemplo2-Pandas-02.ipynb*
# data/                       Ejemplo-Pandas-01.ipynb*
# Ejemplo01.ipynb             Ejemplo-Pandas-Matplotlib.ipynb*

# %%
df = pd.read_csv("data/Matrimonios_2014.csv")

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'ofi_insc', 'prov_insc', 'cant_insc', 'parr_insc',
#        'anio_insc', 'mes_insc', 'dia_insc', 'fecha_insc', 'hijos_rec',
#        'mcap_bie', 'nac_hom', 'cod_paish', 'anio_nach', 'mes_nach', 'dia_nach',
#        'fecha_nach', 'edad_hom', 'nmatanth', 'est_civih', 'p_etnica_hom',
#        'sabe_leerh', 'niv_insth', 'prov_habh', 'cant_habh', 'parr_habh',
#        'area_hom', 'nac_muj', 'cod_paism', 'anio_nacm', 'mes_nacm', 'dia_nacm',
#        'fecha_nacm', 'edad_muj', 'nmatantm', 'est_civim', 'p_etnica_muj',
#        'sabe_leerm', 'niv_instm', 'prov_habm', 'cant_habm', 'parr_habm',
#        'area_muj'],
#       dtype='object')

# %%
df
# Out:
#        Unnamed: 0  ofi_insc    prov_insc    cant_insc  \
# 0               1         2    Pichincha        Quito
# 1               2         2    Pichincha        Quito
# 2               3         2    Pichincha        Quito
# 3               4         2    Pichincha        Quito
# 4               5         2    Pichincha        Quito
# ...           ...       ...          ...          ...
# 60323       60324         1  Santa Elena  Santa Elena
# 60324       60325         1     Los Ríos     Babahoyo
# 60325       60326         1  Santa Elena  Santa Elena
# 60326       60327         1  Santa Elena  Santa Elena
# 60327       60328         1     Los Ríos     Babahoyo
#
#                                                parr_insc  anio_insc  \
# 0                                              Iñaquito        2014
# 1                                              Iñaquito        2014
# 2                                              Iñaquito        2014
# 3                                              Iñaquito        2014
# 4                                              Iñaquito        2014
# ...                                                  ...        ...
# 60323  Santa Elena, cabecera cantonal y capital provi...       2014
# 60324   Babahoyo, cabecera cantonal y capital provincial       2014
# 60325  Santa Elena, cabecera cantonal y capital provi...       2014
# 60326  Santa Elena, cabecera cantonal y capital provi...       2014
# 60327   Babahoyo, cabecera cantonal y capital provincial       2014
#
#            mes_insc  dia_insc    fecha_insc  hijos_rec  ... edad_muj nmatantm  \
# 0       Septiembre         18  1.363038e+10          0  ...       26        0
# 1       Septiembre         18  1.363038e+10          0  ...       26        0
# 2       Septiembre         18  1.363038e+10          0  ...       26        0
# 3       Septiembre         18  1.363038e+10          0  ...       29        0
# 4       Septiembre         18  1.363038e+10          0  ...       26        0
# ...             ...       ...           ...        ...  ...      ...      ...
# 60323    Diciembre         12  1.363772e+10          0  ...       18        0
# 60324    Diciembre         22  1.363859e+10          0  ...       80        0
# 60325    Diciembre         29  1.363919e+10          0  ...       46        0
# 60326    Diciembre         24  1.363876e+10          0  ...       20        0
# 60327    Diciembre         29  1.363919e+10          1  ...       30        0
#
#       est_civim  p_etnica_muj sabe_leerm                      niv_instm  \
# 0       Soltera       Mestiza         Si                       Superior
# 1       Soltera       Mestiza         Si                      Se ignora
# 2       Soltera       Mestiza         Si                      Se ignora
# 3       Soltera      Ignorado         Si                      Se ignora
# 4       Soltera       Mestiza         Si                      Se ignora
# ...         ...           ...        ...                            ...
# 60323   Soltera       Mestiza         Si          Ciclo posbachillerato
# 60324   Soltera       Mestiza         Si                     Secundaria
# 60325   Soltera       Mestiza         Si  Educación media /bachillerato
# 60326   Soltera       Mestiza         Si               Educación básica
# 60327   Soltera       Mestiza         Si               Educación básica
#
#          prov_habm    cant_habm  \
# 0        Pichincha        Quito
# 1        Pichincha        Quito
# 2        Pichincha        Quito
# 3        Pichincha        Quito
# 4        Pichincha        Quito
# ...            ...          ...
# 60323  Santa Elena  Santa Elena
# 60324     Los Ríos     Montalvo
# 60325  Santa Elena      Salinas
# 60326  Santa Elena  Santa Elena
# 60327     Los Ríos     Montalvo
#
#                                                parr_habm area_muj
# 0      Quito Distrito Metropolitano, cabecera cantona...   Urbana
# 1      Quito Distrito Metropolitano, cabecera cantona...   Urbana
# 2      Quito Distrito Metropolitano, cabecera cantona...   Urbana
# 3      Quito Distrito Metropolitano, cabecera cantona...   Urbana
# 4      Quito Distrito Metropolitano, cabecera cantona...   Urbana
# ...                                                  ...      ...
# 60323  Santa Elena, cabecera cantonal y capital provi...   Urbana
# 60324                        Montalvo, cabecera cantonal   Urbana
# 60325                           José Luis Tamayo (Muey)     Rural
# 60326                                           Chanduy     Rural
# 60327                        Montalvo, cabecera cantonal   Urbana
#
# [60328 rows x 43 columns]

# %%
df.mes_insc.value_counts()[:12].sort_values(inplace=False).plot(kind='barh');

# %%
df[df['prov_insc'].str.strip()=='Guayas'].mes_insc.value_counts(normalize=True)\
.sort_values(inplace=False).plot(kind='barh');

# %%
df[df['prov_insc'].str.strip()=='Loja'].mes_insc.value_counts(normalize=True)\
.sort_values(inplace=False).plot(kind='barh');
