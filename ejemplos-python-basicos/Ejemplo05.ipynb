# %%
lista1 = []

lista2 = ["a", 1, [], "b"]

lista3 = [1]
lista3.append("b")
lista3.append("c")
lista3.append(10)



for i in lista2:
    print(i)

print("----------------------")

for i in lista3:
    print(i)
# Out:
# a
# 1
# []
# b
# ----------------------
# 1
# b
# c
# 10
